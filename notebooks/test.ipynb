# %%
import os
import torch

from os.path import dirname

root_dir = dirname(os.getcwd())
os.chdir(root_dir)

# %%
import pandas as pd
import torch

# %%
csv_path = 'data/configs/ranges.csv'
range_df = pd.read_csv(csv_path)

# %%
range_df['Parameters'].to_list()
