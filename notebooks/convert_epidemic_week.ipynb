# %%
import os
from os.path import dirname

root_dir = dirname(os.getcwd())
os.chdir(root_dir)

# %%
import yaml

with open('data/configs/weather_data_params.yaml', 'r') as file:
    location_params = yaml.safe_load(file)

# %%
from datetime import datetime, timedelta
from src.utils.data import get_isoweek_start_date, get_isoweek_date, get_date_after_delta

# %%
calibration_bello_start = get_isoweek_start_date(2014, 8)
calibration_iquitos_start = get_isoweek_start_date(2005, 6)
calibration_sanjuan_start = get_isoweek_start_date(2000, 51)
calibration_vietnam_start = get_isoweek_start_date(2017, 9)
calibration_philippines_start = get_isoweek_start_date(2013, 9)
calibration_cambodia_start = get_isoweek_start_date(2013, 5)

calibration_bello_end = get_date_after_delta(calibration_bello_start)
calibration_iquitos_end = get_date_after_delta(calibration_iquitos_start)
calibration_sanjuan_end = get_date_after_delta(calibration_sanjuan_start)
calibration_vietnam_end = get_date_after_delta(calibration_vietnam_start)
calibration_philippines_end = get_date_after_delta(calibration_philippines_start)
calibration_cambodia_end = get_date_after_delta(calibration_cambodia_start)

# %%
projection_bello_start = get_isoweek_start_date(2006, 32)
projection_iquitos_start = get_isoweek_start_date(2001, 47)
projection_sanjuan_start = get_isoweek_start_date(1998, 52)
projection_vietnam_start = get_isoweek_start_date(2018, 16)
projection_philippines_start = get_isoweek_start_date(2015, 13)
projection_cambodia_start = get_isoweek_start_date(2011, 9)

projection_bello_end = get_date_after_delta(projection_bello_start)
projection_iquitos_end = get_date_after_delta(projection_iquitos_start)
projection_sanjuan_end = get_date_after_delta(projection_sanjuan_start)
projection_vietnam_end = get_date_after_delta(projection_vietnam_start)
projection_philippines_end = get_date_after_delta(projection_philippines_start)
projection_cambodia_end = get_date_after_delta(projection_cambodia_start)

# %%
# calibration_bello_start = get_isoweek_date(2014, 8)
# calibration_bello_end = get_isoweek_date(2015, 2)

# calibration_iquitos_start = get_isoweek_date(2005, 6)
# calibration_iquitos_end = get_isoweek_date(2006, 1)

# calibration_sanjuan_start = get_isoweek_date(2000, 51)
# calibration_sanjuan_end = get_isoweek_date(2001, 46)

# calibration_vietnam_start = get_isoweek_date(2017, 9)
# calibration_vietnam_end = get_isoweek_date(2018, 4)

# calibration_philippines_start = get_isoweek_date(2013, 9)
# calibration_philippines_end = get_isoweek_date(2014, 5)

# calibration_cambodia_start = get_isoweek_date(2013, 5)
# calibration_cambodia_end = get_isoweek_date(2013, 48)

# %%
# projection_bello_start = get_isoweek_date(2006, 32)
# projection_bello_end = get_isoweek_date(2007, 27)

# projection_iquitos_start = get_isoweek_date(2001, 47)
# projection_iquitos_end = get_isoweek_date(2002, 42)

# projection_sanjuan_start = get_isoweek_date(1998, 52)
# projection_sanjuan_end = get_isoweek_date(1999, 47)

# projection_vietnam_start = get_isoweek_date(2018, 16)
# projection_vietnam_end = get_isoweek_date(2019, 12)

# projection_philippines_start = get_isoweek_date(2015, 13)
# projection_philippines_end = get_isoweek_date(2016, 9)

# projection_cambodia_start = get_isoweek_date(2011, 9)
# projection_cambodia_end = get_isoweek_date(2012, 5)

# %%
import copy
params = copy.deepcopy(location_params)

# %%
params['data_split']['calibration']['start_date']['bello'] = str(calibration_bello_start)
params['data_split']['calibration']['start_date']['iquitos'] = str(calibration_iquitos_start)
params['data_split']['calibration']['start_date']['sanjuan'] = str(calibration_sanjuan_start)
params['data_split']['calibration']['start_date']['vietnam'] = str(calibration_vietnam_start)
params['data_split']['calibration']['start_date']['philippines'] = str(calibration_philippines_start)
params['data_split']['calibration']['start_date']['cambodia'] = str(calibration_cambodia_start)

params['data_split']['calibration']['end_date']['bello'] = str(calibration_bello_end)
params['data_split']['calibration']['end_date']['iquitos'] = str(calibration_iquitos_end)
params['data_split']['calibration']['end_date']['sanjuan'] = str(calibration_sanjuan_end)
params['data_split']['calibration']['end_date']['vietnam'] = str(calibration_vietnam_end)
params['data_split']['calibration']['end_date']['philippines'] = str(calibration_philippines_end)
params['data_split']['calibration']['end_date']['cambodia'] = str(calibration_cambodia_end)

# %%
params['data_split']['projection']['start_date']['bello'] = str(projection_bello_start)
params['data_split']['projection']['start_date']['iquitos'] = str(projection_iquitos_start)
params['data_split']['projection']['start_date']['sanjuan'] = str(projection_sanjuan_start)
params['data_split']['projection']['start_date']['vietnam'] = str(projection_vietnam_start)
params['data_split']['projection']['start_date']['philippines'] = str(projection_philippines_start)
params['data_split']['projection']['start_date']['cambodia'] = str(projection_cambodia_start)

params['data_split']['projection']['end_date']['bello'] = str(projection_bello_end)
params['data_split']['projection']['end_date']['iquitos'] = str(projection_iquitos_end)
params['data_split']['projection']['end_date']['sanjuan'] = str(projection_sanjuan_end)
params['data_split']['projection']['end_date']['vietnam'] = str(projection_vietnam_end)
params['data_split']['projection']['end_date']['philippines'] = str(projection_philippines_end)
params['data_split']['projection']['end_date']['cambodia'] = str(projection_cambodia_end)

# %%
# params['data_split']['calibration']['start_date']['bello'] = str(calibration_bello_start[0])
# params['data_split']['calibration']['end_date']['bello'] = str(calibration_bello_end[1])

# params['data_split']['calibration']['start_date']['iquitos'] = str(calibration_iquitos_start[0])
# params['data_split']['calibration']['end_date']['iquitos'] = str(calibration_iquitos_end[1])

# params['data_split']['calibration']['start_date']['sanjuan'] = str(calibration_sanjuan_start[0])
# params['data_split']['calibration']['end_date']['sanjuan'] = str(calibration_sanjuan_end[1])

# params['data_split']['calibration']['start_date']['vietnam'] = str(calibration_vietnam_start[0])
# params['data_split']['calibration']['end_date']['vietnam'] = str(calibration_vietnam_end[1])

# params['data_split']['calibration']['start_date']['philippines'] = str(calibration_philippines_start[0])
# params['data_split']['calibration']['end_date']['philippines'] = str(calibration_philippines_end[1])

# params['data_split']['calibration']['start_date']['cambodia'] = str(calibration_cambodia_start[0])
# params['data_split']['calibration']['end_date']['cambodia'] = str(calibration_cambodia_end[1])

# %%
# params['data_split']['projection']['start_date']['bello'] = str(projection_bello_start[0])
# params['data_split']['projection']['end_date']['bello'] = str(projection_bello_end[1])

# params['data_split']['projection']['start_date']['iquitos'] = str(projection_iquitos_start[0])
# params['data_split']['projection']['end_date']['iquitos'] = str(projection_iquitos_end[1])

# params['data_split']['projection']['start_date']['sanjuan'] = str(projection_sanjuan_start[0])
# params['data_split']['projection']['end_date']['sanjuan'] = str(projection_sanjuan_end[1])

# params['data_split']['projection']['start_date']['vietnam'] = str(projection_vietnam_start[0])
# params['data_split']['projection']['end_date']['vietnam'] = str(projection_vietnam_end[1])

# params['data_split']['projection']['start_date']['philippines'] = str(projection_philippines_start[0])
# params['data_split']['projection']['end_date']['philippines'] = str(projection_philippines_end[1])

# params['data_split']['projection']['start_date']['cambodia'] = str(projection_cambodia_start[0])
# params['data_split']['projection']['end_date']['cambodia'] = str(projection_cambodia_end[1])

# %%
with open('data/configs/weather_data_params.yaml', 'w') as out:
    yaml.safe_dump(params, out, sort_keys=False)
